# %%
# %load_ext autoreload
# %autoreload 2

# %%
from pyspark.sql import SparkSession

SparkSession.builder.getOrCreate()

# %%
# !pip install polars

# %%
from src.configs import BenchmarksConfig
from src.manager import BenchmarksManager

# %%
cfg = BenchmarksConfig.load_from_json("benchmarks_config/databricks/small.json")
manager = BenchmarksManager(configs=cfg)
result = manager.run()
# print(result)

# %%
import os
from glob import glob

path = 'abfss://backblaze@diplomadata.dfs.core.windows.net/data/backblaze_drive/2023/Q1/'
# pattern = os.path.join(path, "**", "*.csv")
all_files = glob(path, recursive=True)
print(path)
print(all_files)
# if not all_files: raise FileNotFoundError(f"No CSV files found in {self.base_dir}")
# if self.shuffle: random.shuffle(all_files)
# if self.n_files: all_files = all_files[: self.n_files]
# return all_files
# display(spark.read.csv(path, header=True))
